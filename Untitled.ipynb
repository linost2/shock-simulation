# %%
import pandas as pd
df=pd.read_excel(r'D:\Youlin Zhu\2021实验室\分子动力学\数据处理\strainrate\sample40\fullfill.xlsx',header=0)
k=df.shape[0]
index_to_drop=[]
index_to_drop.append(k-1)

# %%
print(index_to_drop)
# Out:
# [30956]

# %%
for i in df.index:
    if df.iloc[i,0]>200:
        index_to_drop.append(i-1)

# %%
print(index_to_drop)
# Out:
# [30956, 75, 151, 226, 301, 376, 451, 525, 599, 673, 747, 820, 893, 966, 1039, 1111, 1183, 1255, 1327, 1399, 1471, 1543, 1615, 1687, 1759, 1831, 1903, 1975, 2047, 2119, 2191, 2263, 2335, 2407, 2479, 2552, 2625, 2698, 2771, 2845, 2919, 2993, 3067, 3142, 3217, 3292, 3367, 3443, 3519, 3595, 3671, 3748, 3825, 3902, 3979, 4056, 4134, 4212, 4290, 4368, 4447, 4526, 4605, 4684, 4763, 4843, 4923, 5003, 5083, 5163, 5244, 5325, 5406, 5487, 5568, 5649, 5730, 5812, 5894, 5976, 6058, 6140, 6222, 6304, 6386, 6468, 6550, 6632, 6715, 6797, 6879, 6961, 7043, 7125, 7207, 7289, 7371, 7453, 7535, 7617, 7699, 7781, 7863, 7945, 8027, 8109, 8190, 8271, 8352, 8433, 8514, 8595, 8676, 8757, 8838, 8919, 9000, 9081, 9162, 9243, 9323, 9403, 9483, 9563, 9643, 9723, 9803, 9882, 9961, 10040, 10119, 10198, 10277, 10355, 10433, 10511, 10589, 10667, 10744, 10821, 10898, 10975, 11052, 11129, 11205, 11281, 11357, 11433, 11509, 11585, 11661, 11736, 11811, 11886, 11961, 12036, 12111, 12186, 12261, 12336, 12411, 12486, 12561
# ...

# %%
df.drop(df.index[index_to_drop],inplace=True)

# %%
df.to_excel(r'D:\Youlin Zhu\2021实验室\分子动力学\数据处理\strainrate\sample40\cut.xlsx',index=False)
